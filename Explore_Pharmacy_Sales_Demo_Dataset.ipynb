# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosalinas777/hospitaldata/blob/main/Explore_Pharmacy_Sales_Demo_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_pharmacy_sales=pd.read_csv('/content/drive/MyDrive/linkedin learning/Demo Pharmacy Sales Data.csv')
df_pharmacy_sales
# Out:
#          Date Sold                                     Med_name  \
# 0       2021-05-07              Clotrimazole Topical Cream (2%)
# 1       2021-08-09   Alprostadil Urethral Suppository (125 mcg)
# 2       2021-06-15            Methyltestosterone Tablet (10 mg)
# 3       2021-02-19                      Buspirone Tablet (5 mg)
# 4       2022-09-24  Hydrocodone/Acetaminophen Tablet (5/325 mg)
# ...            ...                                          ...
# 999995  2020-11-29   Alprostadil Urethral Suppository (125 mcg)
# 999996  2021-03-30                   Fenoprofen Tablet (600 mg)
# 999997  2020-04-17                      Doxazosin Tablet (1 mg)
# 999998  2021-12-08             Flumazenil Injection (0.1 mg/mL)
# 999999  2022-08-16                   Prednisolone Tablet (5 mg)
#
#                                       Med_class  Quantity Sold  Price
# 0                                    Antifungal             66   86.9
# ...

# %%
df_pharmacy_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Date Sold      1000000 non-null  object
#  1   Med_name       1000000 non-null  object
#  2   Med_class      1000000 non-null  object
#  3   Quantity Sold  1000000 non-null  int64
#  4   Price          1000000 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 38.1+ MB

# %%
summary_stats=df_pharmacy_sales[['Quantity Sold','Price']].describe()
summary_stats
# Out:
#         Quantity Sold           Price
# count  1000000.000000  1000000.000000
# mean        50.524566       50.024411
# std         28.847235       28.872706
# min          1.000000        0.100000
# 25%         26.000000       25.000000
# 50%         51.000000       50.000000
# 75%         75.000000       75.100000
# max        100.000000      100.000000

# %%
df_pharmacy_sales['Quantity Sold'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Quantity Sold')
plt.show()

# %%
plt.subplot(1,2,1)
df_pharmacy_sales['Quantity Sold'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Quantity Sold')

plt.subplot(1,2,2)
df_pharmacy_sales['Price'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Price')

plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
df_pharmacy_sales['Quantity Sold'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Quantity Sold')

plt.subplot(1,2,2)
df_pharmacy_sales['Price'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Price')

plt.show()

# %%
plt.subplot(1,2,1)
sns.histplot(df_pharmacy_sales['Quantity Sold'],bins=20, kde=True, color='skyblue')
plt.title('Histogram of Quantity Sold')

plt.subplot(1,2,2)
sns.histplot(df_pharmacy_sales['Price'],bins=20, kde=True, color='Purple')
plt.title('Histogram of Price')

plt.show()

# %%
#Medication class analysis

# %%
from wordcloud import WordCloud

# %%
df_pharmacy_sales
# Out:
#          Date Sold                                     Med_name  \
# 0       2021-05-07              Clotrimazole Topical Cream (2%)
# 1       2021-08-09   Alprostadil Urethral Suppository (125 mcg)
# 2       2021-06-15            Methyltestosterone Tablet (10 mg)
# 3       2021-02-19                      Buspirone Tablet (5 mg)
# 4       2022-09-24  Hydrocodone/Acetaminophen Tablet (5/325 mg)
# ...            ...                                          ...
# 999995  2020-11-29   Alprostadil Urethral Suppository (125 mcg)
# 999996  2021-03-30                   Fenoprofen Tablet (600 mg)
# 999997  2020-04-17                      Doxazosin Tablet (1 mg)
# 999998  2021-12-08             Flumazenil Injection (0.1 mg/mL)
# 999999  2022-08-16                   Prednisolone Tablet (5 mg)
#
#                                       Med_class  Quantity Sold  Price
# 0                                    Antifungal             66   86.9
# ...

# %%
df_pharmacy_sales['Med_name'].value_counts()
# Out:
# Med_name
# Tretinoin Topical Cream (0.025%)                     15027
# Ketoconazole Topical Cream (2%)                      11008
# Adapalene/Benzoyl Peroxide Topical Gel (0.1/2.5%)    10097
# Triamcinolone Topical Ointment (0.1%)                10083
# Clobetasol Topical Cream (0.05%)                      9984
#                                                      ...
# Guanfacine Tablet (2 mg)                               939
# Olopatadine Nasal Spray (665 mcg/spray)                938
# Methylphenidate Tablet (10 mg)                         938
# Lithium Carbonate Capsule (300 mg)                     920
# Clindamycin Topical Lotion (1%)                        917
# Name: count, Length: 279, dtype: int64

# %%
#length: means how many distinct values exist

# %%
df_pharmacy_sales['Med_class'].value_counts()
# Out:
# Med_class
#  Nonsteroidal Anti-Inflammatory Drug                        82146
#  Phosphodiesterase Type 5 Inhibitor                         56294
#  Alpha-Blocker                                              52208
#  Anticonvulsant                                             49766
#  Beta-Blocker                                               40673
#                                                             ...
#  Norepinephrine Reuptake Inhibitor                            995
#  Melatonin Receptor Agonist                                   983
#  Cardiac Glycoside                                            981
#  Anticholinergic/Short-Acting Beta-2 Agonist Combination      977
#  Mood Stabilizer                                              920
# Name: count, Length: 87, dtype: int64

# %%
top_number=30

# %%
top_classes=df_pharmacy_sales['Med_class'].value_counts().nlargest(top_number).index
top_classes
# Out:
# Index([' Nonsteroidal Anti-Inflammatory Drug',
#        ' Phosphodiesterase Type 5 Inhibitor', ' Alpha-Blocker',
#        ' Anticonvulsant', ' Beta-Blocker', ' Antifungal', ' Corticosteroid',
#        ' Benzodiazepine', ' Low-Potency Corticosteroid',
#        ' High-Potency Corticosteroid', ' Opioid Analgesic', ' Antibiotic',
#        ' Inhaled Corticosteroid', ' 5-Alpha Reductase Inhibitor', ' Analgesic',
#        ' Prostaglandin E1 Analog', ' Retinoid', ' Sympathomimetic',
#        ' Vasodilator', ' Alpha-2 Agonist',
#        ' Disease-Modifying Antirheumatic Drug', ' Anticholinergic',
#        ' Androgen Hormone', ' Leukotriene Receptor Antagonist',
#        ' Long-Acting Beta-2 Agonist', ' Antibiotic/Acne Treatment Combination',
#        ' Retinoid/Acne Treatment Combination', ' Anxiolytic',
#        ' Inhaled Corticosteroid/Long-Acting Beta-2 Agonist Combination',
#        ' Short-Acting Beta-2 Agonist'],
#       dtype='object', name='Med_class')

# %%
df_top_med_classes=df_pharmacy_sales[df_pharmacy_sales['Med_class'].isin(top_classes)]
df_top_med_classes
# Out:
#          Date Sold                                    Med_name  \
# 0       2021-05-07             Clotrimazole Topical Cream (2%)
# 1       2021-08-09  Alprostadil Urethral Suppository (125 mcg)
# 2       2021-06-15           Methyltestosterone Tablet (10 mg)
# 3       2021-02-19                     Buspirone Tablet (5 mg)
# 6       2018-10-22          Norepinephrine Injection (2 mg/mL)
# ...            ...                                         ...
# 999994  2019-02-08       Formoterol Inhaler (12 mcg/actuation)
# 999995  2020-11-29  Alprostadil Urethral Suppository (125 mcg)
# 999996  2021-03-30                  Fenoprofen Tablet (600 mg)
# 999997  2020-04-17                     Doxazosin Tablet (1 mg)
# 999999  2022-08-16                  Prednisolone Tablet (5 mg)
#
#                                    Med_class  Quantity Sold  Price
# 0                                 Antifungal             66   86.9
# 1                    Prostaglandin E1 Analog             15   22.9
# ...

# %%
df_top_med_classes=df_top_med_classes.groupby('Med_class')['Quantity Sold'].sum()
df_top_med_classes
# Out:
# Med_class
#  5-Alpha Reductase Inhibitor                                      1101549
#  Alpha-2 Agonist                                                   802378
#  Alpha-Blocker                                                    2625280
#  Analgesic                                                        1061008
#  Androgen Hormone                                                  609408
#  Antibiotic                                                       1259910
#  Antibiotic/Acne Treatment Combination                             508238
#  Anticholinergic                                                   704616
#  Anticonvulsant                                                   2514863
#  Antifungal                                                       1819102
#  Anxiolytic                                                        508730
#  Benzodiazepine                                                   1705063
#  Beta-Blocker                                                     2062362
# ...

# %%
type(df_top_med_classes)
# Out:
# pandas.core.series.Series

# %%
df_top_med_classes.sort_values(by='Quantity Sold')
#not able to sort above because the df is a series and it needs to be a dataframe
#to fix this I rerun the below code
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-430cf7c6b363> in <cell line: 1>()
# ----> 1 df_top_med_classes.sort_values(by='Quantity Sold')
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
df_top_med_classes=df_pharmacy_sales[df_pharmacy_sales['Med_class'].isin(top_classes)]
df_top_med_classes
# Out:
#          Date Sold                                    Med_name  \
# 0       2021-05-07             Clotrimazole Topical Cream (2%)
# 1       2021-08-09  Alprostadil Urethral Suppository (125 mcg)
# 2       2021-06-15           Methyltestosterone Tablet (10 mg)
# 3       2021-02-19                     Buspirone Tablet (5 mg)
# 6       2018-10-22          Norepinephrine Injection (2 mg/mL)
# ...            ...                                         ...
# 999994  2019-02-08       Formoterol Inhaler (12 mcg/actuation)
# 999995  2020-11-29  Alprostadil Urethral Suppository (125 mcg)
# 999996  2021-03-30                  Fenoprofen Tablet (600 mg)
# 999997  2020-04-17                     Doxazosin Tablet (1 mg)
# 999999  2022-08-16                  Prednisolone Tablet (5 mg)
#
#                                    Med_class  Quantity Sold  Price
# 0                                 Antifungal             66   86.9
# 1                    Prostaglandin E1 Analog             15   22.9
# ...

# %%
#then reset the below index from the beginning and it comes back as a dataframe, now I can test to see which type of data it is, and the continue with the groupby
df_top_med_classes=df_top_med_classes.groupby('Med_class')['Quantity Sold'].sum().reset_index()
df_top_med_classes
# Out:
#                                             Med_class  Quantity Sold
# 0                         5-Alpha Reductase Inhibitor        1101549
# 1                                     Alpha-2 Agonist         802378
# 2                                       Alpha-Blocker        2625280
# 3                                           Analgesic        1061008
# 4                                    Androgen Hormone         609408
# 5                                          Antibiotic        1259910
# 6               Antibiotic/Acne Treatment Combination         508238
# 7                                     Anticholinergic         704616
# 8                                      Anticonvulsant        2514863
# 9                                          Antifungal        1819102
# 10                                         Anxiolytic         508730
# 11                                     Benzodiazepine        1705063
# 12                                       Beta-Blocker        2062362
# ...

# %%
type(df_top_med_classes)
# Out:
# pandas.core.frame.DataFrame

# %%
df_top_med_classes1=df_top_med_classes.sort_values(by='Quantity Sold')
df_top_med_classes1
# Out:
#                                             Med_class  Quantity Sold
# 17   Inhaled Corticosteroid/Long-Acting Beta-2 Ago...         500737
# 27                        Short-Acting Beta-2 Agonist         506914
# 6               Antibiotic/Acne Treatment Combination         508238
# 10                                         Anxiolytic         508730
# 26                Retinoid/Acne Treatment Combination         509386
# 19                         Long-Acting Beta-2 Agonist         521905
# 18                    Leukotriene Receptor Antagonist         602074
# 4                                    Androgen Hormone         609408
# 7                                     Anticholinergic         704616
# 14               Disease-Modifying Antirheumatic Drug         767315
# 1                                     Alpha-2 Agonist         802378
# 29                                        Vasodilator         973025
# 28                                    Sympathomimetic        1005189
# ...

# %%
#lets visualize as a horizontal bar chart
plt.barh(df_top_med_classes1['Med_class'],df_top_med_classes1['Quantity Sold'])
plt.title(f'Top{top_number} Medication Classes by Quantity Sold')
plt.xlabel('Quantity Sold')
plt.ylabel('Medication Class')
plt.show()

# %%
med_classes=df_pharmacy_sales['Med_class'].str.cat(sep='')
wordcloud=WordCloud(width=800,height=400).generate(med_classes)
plt.figure(figsize=(14,7))
plt.imshow(wordcloud,interpolation='bilinear')
plt.show()

# %%
med_classes=df_pharmacy_sales['Med_name'].str.cat(sep='')
wordcloud=WordCloud(width=800,height=400).generate(med_classes)
plt.figure(figsize=(14,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.show()

# %%
#medication demand forecast using prophet

# %%
import prophet
from prophet import Prophet

# %%
df_pharmacy_sales
# Out:
#          Date Sold                                     Med_name  \
# 0       2021-05-07              Clotrimazole Topical Cream (2%)
# 1       2021-08-09   Alprostadil Urethral Suppository (125 mcg)
# 2       2021-06-15            Methyltestosterone Tablet (10 mg)
# 3       2021-02-19                      Buspirone Tablet (5 mg)
# 4       2022-09-24  Hydrocodone/Acetaminophen Tablet (5/325 mg)
# ...            ...                                          ...
# 999995  2020-11-29   Alprostadil Urethral Suppository (125 mcg)
# 999996  2021-03-30                   Fenoprofen Tablet (600 mg)
# 999997  2020-04-17                      Doxazosin Tablet (1 mg)
# 999998  2021-12-08             Flumazenil Injection (0.1 mg/mL)
# 999999  2022-08-16                   Prednisolone Tablet (5 mg)
#
#                                       Med_class  Quantity Sold  Price
# 0                                    Antifungal             66   86.9
# ...

# %%
df_pharmacy_sales[df_pharmacy_sales['Med_class'].str.contains('Anxiolytic')][['Date Sold','Quantity Sold']]
# Out:
#          Date Sold  Quantity Sold
# 3       2021-02-19             89
# 122     2022-03-01             82
# 143     2020-08-11             17
# 327     2020-12-08             86
# 518     2019-03-31             70
# ...            ...            ...
# 999594  2019-08-11             42
# 999711  2020-05-16             71
# 999772  2019-09-02             63
# 999883  2019-09-09             38
# 999929  2023-03-25              4
#
# [10004 rows x 2 columns]

# %%
df_prophet=df_pharmacy_sales[df_pharmacy_sales['Med_class'].str.contains('Anxiolytic')][['Date Sold','Quantity Sold']]

# %%
df_prophet=df_prophet.reset_index()
df_prophet
# Out:
#         index   Date Sold  Quantity Sold
# 0           3  2021-02-19             89
# 1         122  2022-03-01             82
# 2         143  2020-08-11             17
# 3         327  2020-12-08             86
# 4         518  2019-03-31             70
# ...       ...         ...            ...
# 9999   999594  2019-08-11             42
# 10000  999711  2020-05-16             71
# 10001  999772  2019-09-02             63
# 10002  999883  2019-09-09             38
# 10003  999929  2023-03-25              4
#
# [10004 rows x 3 columns]

# %%
df_prophet=df_prophet.rename(columns={'Date Sold': 'ds', 'Quantity Sold':'y'})
df_prophet
# Out:
#         index          ds   y
# 0           3  2021-02-19  89
# 1         122  2022-03-01  82
# 2         143  2020-08-11  17
# 3         327  2020-12-08  86
# 4         518  2019-03-31  70
# ...       ...         ...  ..
# 9999   999594  2019-08-11  42
# 10000  999711  2020-05-16  71
# 10001  999772  2019-09-02  63
# 10002  999883  2019-09-09  38
# 10003  999929  2023-03-25   4
#
# [10004 rows x 3 columns]

# %%
type(df_prophet['ds'][0])
# Out:
# str

# %%
df_prophet['ds']=pd.to_datetime(df_prophet['ds'])

# %%
  type(df_prophet['ds'][0])
  #the abobe data type changed to the datetime which is useful for the model we will do
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
model=Prophet()

# %%
model.fit(df_prophet)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp09foorat/ds965tis.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp09foorat/h8py4yp5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45258', 'data', 'file=/tmp/tmp09foorat/ds965tis.json', 'init=/tmp/tmp09foorat/h8py4yp5.json', 'output', 'file=/tmp/tmp09foorat/prophet_modelwi2fj2ql/prophet_model-20240530142509.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:25:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:25:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future=model.make_future_dataframe(periods=365)
forecast=model.predict(future)

# %%
fig=model.plot(forecast)
plt.show()

# %%
fig=model.plot_components(forecast)
plt.show()
#peak of anxiolytic use was in 202

# %%
#medication demand forecast using prophet

# %%
def medication_quantity_forecaster(df, med_class=None, med_name=None):
  if med_class:
    df_filtered=df[df['Med_class'].str.contains(med_class)]
  elif med_name:
    df_filtered=df[df['Med_name'].str.contains(med_name)]
  else:
    raise ValueError('Specify either med_name or medclass for filtering')

  df_filtered=df_filtered[['Date Sold','Quantity Sold']].copy()
  df_filtered=df_filtered.reset_index()
  df_filtered=df_filtered.rename(columns={'Date Sold':'ds','Quantity Sold':'y'})
  df_filtered['ds']=pd.to_datetime(df_filtered['ds'])

  model=Prophet()
  model.fit(df_filtered)

  future=model.make_future_dataframe(periods=365)
  forecast=model.predict(future)

  fig1=model.plot(forecast)
  plt.title(f'Medication Quantity Forecast({med_class or med_name})')
  plt.xlabel('Date')
  plt.ylabel('Quantity Sold')
  plt.show()

  fig2=model.plot_components(forecast)
  plt.show()
  return fig1, fig2

# %%
medication_quantity_forecaster(df_pharmacy_sales,med_class='Anxiolytic')
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp09foorat/iqf_qhk6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp09foorat/psk4gjik.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3313', 'data', 'file=/tmp/tmp09foorat/iqf_qhk6.json', 'init=/tmp/tmp09foorat/psk4gjik.json', 'output', 'file=/tmp/tmp09foorat/prophet_model6os0chbe/prophet_model-20240530145225.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:52:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:52:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# (<Figure size 1000x600 with 1 Axes>, <Figure size 900x900 with 3 Axes>)

# %%
#function works well we have the medication quantity forecast for anxiolytic and we did not need to do this one by one, and
#then we had the foreast per year, per day of the week and per month
#we succesfully wrote a function so we dont have to rewrite the code every time we want to do this prophet forecasting for any data in our dataset
